# %%
import os
import json
import pandas as pd
import ast

class PREPARE_DATASET():
    def __init__(
        self,
        data_file_path: str
    ) -> None:
        self.data_file_path = data_file_path
        self.out_file = os.path.join(os.getcwd(), 'processed_seed_tasks.jsonl')

        self.data = []
        self.processed_data = []

    
    def load_data(
        self
    ):
        f = open(self.data_file_path)
        self.data = [json.loads(line) for line in f]
        f.close()
        print(f'Total samples: {len(self.data)}')
    

    def process_data(
        self
    ):
        for line in self.data[:2]:
            print(line)
            # self.processed_data.append(line)
    
    
    def load_data_in_df(
        self
    ):
        self.data = pd.read_json(self.data_file_path, lines=True)
        print(f'Total samples: {self.data.shape}')

    
    def process_data_in_df(
        self
    ):
        self.data['category'] = self.data.is_classification.apply(lambda x: 'classification' if x==True else 'other')
        self.data = self.data[['instruction', 'instances', 'category']]
        # Get Context and Response from input
        self.data['context'] = self.data.instances.apply(
            lambda x: ast.literal_eval(str(x))[0]['input']
        )
        self.data['response'] = self.data.instances.apply(
            lambda x: ast.literal_eval(str(x))[0]['output']
        )
        
        # Select required columns
        self.data = self.data[['instruction', 'context', 'response', 'category']]

    
    def write_data_in_json(
        self
    ):
        self.data.to_json(self.out_file, orient='records', lines=True)

# %%
prepareDatasetObj = PREPARE_DATASET(data_file_path='./seed_tasks.jsonl')
prepareDatasetObj.load_data_in_df()
prepareDatasetObj.process_data_in_df()
prepareDatasetObj.write_data_in_json()
# Out:
# Total samples: (175, 5)

# %%
prepareDatasetObj.load_data_in_df()
# Out:
# Total samples: (175, 5)

# %%
prepareDatasetObj.data.head()
# Out:
#             id                        name  \
# 0  seed_task_0        breakfast_suggestion
# 1  seed_task_1            antonym_relation
# 2  seed_task_2    one_sentence_description
# 3  seed_task_3  harmful_stereotype_example
# 4  seed_task_4    email_subject_generation
#
#                                          instruction  \
# 0  Is there anything I can eat for a breakfast th...
# 1      What is the relation between the given pairs?
# 2  Generate a one-sentence description for each o...
# 3  Describe a situation in which the given stereo...
# 4  Generate an appropriate subjective title for t...
#
#                                            instances  is_classification
# 0  [{'input': '', 'output': 'Yes, you can have 1 ...              False
# 1  [{'input': 'Night : Day :: Right : Left', 'out...              False
# 2  [{'input': '- Brack Obama
# - Elon Musk
# - Taylor...              False
# 3  [{'input': '"All Asians are smart!"', 'output'...              False
# 4  [{'input': 'Hi [person name],
#
# I'm writing to ...              False

# %%
prepareDatasetObj.data[prepareDatasetObj.data.is_classification == False]
# Out:
#                 id                          name  \
# 0      seed_task_0          breakfast_suggestion
# 1      seed_task_1              antonym_relation
# 2      seed_task_2      one_sentence_description
# 3      seed_task_3    harmful_stereotype_example
# 4      seed_task_4      email_subject_generation
# ..             ...                           ...
# 144  seed_task_144         solve_equation_system
# 145  seed_task_145                 plan_syllabus
# 146  seed_task_146            university_ranking
# 147  seed_task_147  rank_countries_by_population
# 149  seed_task_149        stereotype_explanation
#
#                                            instruction  \
# 0    Is there anything I can eat for a breakfast th...
# 1        What is the relation between the given pairs?
# 2    Generate a one-sentence description for each o...
# 3    Describe a situation in which the given stereo...
# 4    Generate an appropriate subjective title for t...
# ..                                                 ...
# 144  Solve the following equation system. Give me t...
# 145                 Plan a syllabus for the the class.
# 146                   Rank the following universities.
# 147          Rank these countries by their population.
# 149  Given a sentence, detect if there is any poten...
#
#                                              instances  is_classification
# 0    [{'input': '', 'output': 'Yes, you can have 1 ...              False
# 1    [{'input': 'Night : Day :: Right : Left', 'out...              False
# 2    [{'input': '- Brack Obama
# - Elon Musk
# - Taylor...              False
# 3    [{'input': '"All Asians are smart!"', 'output'...              False
# 4    [{'input': 'Hi [person name],
#
# I'm writing to ...              False
# ..                                                 ...                ...
# 144  [{'input': '3x - 4y = 1, 2x + 3y = 12', 'outpu...              False
# 145  [{'input': 'Class: NLP for PhD students.', 'ou...              False
# 146  [{'input': 'Princeton, Stanford, UW, Cornell',...              False
# 147  [{'input': 'Brazil, China, US, Japan, Canada, ...              False
# 149  [{'input': 'The next US president should be wh...              False
#
# [149 rows x 5 columns]

# %%
df = pd.read_json('/Users/chintandonda/Downloads/databricks-dolly-15k.jsonl', lines=True)

# %%
df.head()
# Out:
#                                          instruction  \
# 0         When did Virgin Australia start operating?
# 1           Which is a species of fish? Tope or Rope
# 2     Why can camels survive for long without water?
# 3  Alice's parents have three daughters: Amy, Jes...
# 4                    When was Tomoaki Komorida born?
#
#                                              context  \
# 0  Virgin Australia, the trading name of Virgin A...
# 1
# 2
# 3
# 4  Komorida was born in Kumamoto Prefecture on Ju...
#
#                                             response        category
# 0  Virgin Australia commenced services on 31 Augu...       closed_qa
# 1                                               Tope  classification
# 2  Camels use the fat in their humps to keep them...         open_qa
# 3            The name of the third daughter is Alice         open_qa
# 4         Tomoaki Komorida was born on July 10,1981.       closed_qa

# %%
df.category.unique()
# Out:
# array(['closed_qa', 'classification', 'open_qa', 'information_extraction',
#        'brainstorming', 'general_qa', 'summarization', 'creative_writing'],
#       dtype=object)

# %%
df.groupby(['category']).count()
# Out:
#                         instruction  context  response
# category
# brainstorming                  1766     1766      1766
# classification                 2136     2136      2136
# closed_qa                      1773     1773      1773
# creative_writing                709      709       709
# general_qa                     2191     2191      2191
# information_extraction         1506     1506      1506
# open_qa                        3742     3742      3742
# summarization                  1188     1188      1188

# %%
df[df.category == 'classification'].head()
# Out:
#                                           instruction context  \
# 1            Which is a species of fish? Tope or Rope
# 19  Identify which instrument is string or percuss...
#
#                                    response        category
# 1                                      Tope  classification
# 19  Gudok is string, Cantaro is percussion.  classification
